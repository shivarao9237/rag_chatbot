# %%
### Document Structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main content using to create rag",
    metadata={
        "author":"shiva",
        "pages":1
    }
)
doc
# Out:
# Document(metadata={'author': 'shiva', 'pages': 1}, page_content='this is the main content using to create rag')

# %%
#create simple text file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python is a high-level programming language known for being easy to read and simple to learn. It is widely used in web development, data science, automation, artificial intelligence, game development, and more.

What is Python?

Python is an interpreted, object-oriented programming language created by Guido van Rossum and first released in 1991.

Why Python is Popular
Easy syntax → looks closer to English compared to many languages
Beginner friendly → easier to learn than many programming languages
Large community → many tutorials, libraries, and support available
Cross-platform → runs on Windows, Linux, and macOS
Versatile → useful in many fields
Basic Python Example
print("Hello, World!")

Output:

Hello, World!

This simple program prints text on the screen.

Main Features of Python
1. Variables
name = "John"
age = 20
print(name)
print(age)
2. Data Types

Python supports:

Integer → 10
Float → 3.14
String → "Hello"
Boolean → True, False
List → [1,2,3]

Example:

x = 10
y = 3.5
text = "Python"
3. Conditions
age = 18

if age >= 18:
    print("Adult")
else:
    print("Minor")
4. Loops

For loop

for i in range(5):
    print(i)

While loop

count = 0

while count < 5:
    print(count)
    count += 1
5. Functions
def add(a, b):
    return a + b

print(add(5,3))
Where Python is Used
Web development
Machine learning
Artificial intelligence
Data analysis
Automation scripts
Cybersecurity tools
Game development
Advantages

✅ Simple syntax
✅ Large library support
✅ Good community support
✅ Fast development speed

Disadvantages

❌ Slower than some compiled languages
❌ Higher memory usage
❌ Not ideal for some mobile apps

How to Start Learning
Install Python
Learn syntax basics
Practice small programs
Learn functions and data structures
Build projects

A good beginner path is:

Syntax → Variables → Conditions → Loops → Functions → Projects

If you want, I can also give a 
Python roadmap for beginners (30-day plan).""",

"../data/text_files/machine_learning_intro.txt":"""Machine Learning is a branch of computer science where computers learn patterns from data and make predictions or decisions without being explicitly programmed for every task.

## What is Machine Learning?

Machine Learning is a field of study that allows computers to improve performance by learning from data and experience.

Machine Learning is a subset of Artificial Intelligence.

### Simple Idea

Traditional Programming:

**Input + Rules → Output**

Machine Learning:

**Input + Output Data → Learning Algorithm → Model**

The model learns patterns and can make predictions on new data.

## Why Machine Learning is Popular

* Can analyze large amounts of data
* Automates decision making
* Improves accuracy over time
* Used in many real-world applications
* Powers modern AI systems

## Basic Machine Learning Example

Suppose we want to predict house prices.

Data:

```text
Size      Price
1000      10 lakh
1200      12 lakh
1500      15 lakh
```

The ML model learns the relationship between size and price.

Then:

```text
Input: 1300 sqft

Output: Predicted Price
```

## Types of Machine Learning

### 1. Supervised Learning

Learning using labeled data.

Examples:

* Email spam detection
* Price prediction
* Image classification

Common algorithms:

* Linear Regression
* Decision Trees
* Random Forest

### 2. Unsupervised Learning

Learning patterns without labeled outputs.

Examples:

* Customer grouping
* Pattern detection
* Recommendation systems

Common algorithms:

* K-Means Clustering
* PCA
* Association Rules

### 3. Reinforcement Learning

Learning through rewards and penalties.

Examples:

* Robotics
* Self-driving systems
* Game playing AI

## Basic Steps in Machine Learning

### Step 1: Collect Data

Gather information from sources.

Examples:

* Images
* Text
* Sales data
* Sensor data

### Step 2: Prepare Data

Clean and organize data.

Tasks:

* Remove missing values
* Remove duplicates
* Convert formats

### Step 3: Train Model

Feed data into algorithms.

### Step 4: Test Model

Check performance.

### Step 5: Deploy Model

Use the trained model in real applications.

## Important Concepts

### Dataset

Collection of data used for training.

Example:

```text
Age   Salary   Purchased
22    30000    No
30    50000    Yes
```

### Features

Input variables.

Example:

```text
Age
Salary
Experience
```

### Labels

Expected outputs.

Example:

```text
Purchased = Yes/No
```

### Model

A learned system that makes predictions.

## Popular Machine Learning Tools

* Python
* Jupyter Notebook
* TensorFlow
* PyTorch
* scikit-learn

## Where Machine Learning is Used

* Recommendation systems
* Fraud detection
* Medical diagnosis
* Image recognition
* Voice assistants
* Self-driving vehicles
* Predictive analytics

## Advantages

✅ Can find complex patterns
✅ Automates tasks
✅ Works with large data
✅ Improves predictions

## Disadvantages

❌ Requires large datasets
❌ Training can be expensive
❌ Can produce biased results
❌ Sometimes difficult to interpret

## Basic Workflow

```text
Data Collection
       ↓
Data Cleaning
       ↓
Feature Selection
       ↓
Model Training
       ↓
Testing
       ↓
Deployment
```

## How to Start Learning Machine Learning

1. Learn Python basics
2. Learn mathematics (statistics, probability, linear algebra)
3. Learn data analysis
4. Learn ML algorithms
5. Build projects

A beginner learning path:

**Python → Mathematics → Data Analysis → Machine Learning Algorithms → Projects → Deep Learning**

If you want, I can also provide a **Machine Learning roadmap with projects from beginner to advanced level**.
"""
}
for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)
print("sample text files created")
# Out:
# sample text files created

# %%
###text Loader
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level programming language known for being easy to read and simple to learn. It is widely used in web development, data science, automation, artificial intelligence, game development, and more.\n\nWhat is Python?\n\nPython is an interpreted, object-oriented programming language created by Guido van Rossum and first released in 1991.\n\nWhy Python is Popular\nEasy syntax → looks closer to English compared to many languages\nBeginner friendly → easier to learn than many programming languages\nLarge community → many tutorials, libraries, and support available\nCross-platform → runs on Windows, Linux, and macOS\nVersatile → useful in many fields\nBasic Python Example\nprint("Hello, World!")\n\nOutput:\n\nHello, World!\n\nThis simple program prints text on the screen.\n\nMain Features of Python\n1. Variables\nname = "John"\nage = 20\nprint(name)\nprint(age)\n2. Data Types\n\nPython support
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)
documents=dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning_intro.txt'}, page_content='Machine Learning is a branch of computer science where computers learn patterns from data and make predictions or decisions without being explicitly programmed for every task.\n\n## What is Machine Learning?\n\nMachine Learning is a field of study that allows computers to improve performance by learning from data and experience.\n\nMachine Learning is a subset of Artificial Intelligence.\n\n### Simple Idea\n\nTraditional Programming:\n\n**Input + Rules → Output**\n\nMachine Learning:\n\n**Input + Output Data → Learning Algorithm → Model**\n\nThe model learns patterns and can make predictions on new data.\n\n## Why Machine Learning is Popular\n\n* Can analyze large amounts of data\n* Automates decision making\n* Improves accuracy over time\n* Used in many real-world applications\n* Powers modern AI systems\n\n## Basic Machine Learning Example\n\nSuppose we want to predict house prices.\n\n
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)
pdf_documents=dir_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\DST Unit - 2 (1).pdf', 'file_path': '..\\data\\pdf\\DST Unit - 2 (1).pdf', 'total_pages': 21, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-16T05:18:52+00:00', 'trapped': '', 'modDate': 'D:20251216051852Z', 'creationDate': '', 'page': 0}, page_content='2 \n2.1 \n2.2 \nIntroduction to stream processing \nae \neee \nOverview \nStream processing has been a very active and diverse area of research, commercial, \nand open-source development. This diversity of technologies has brought along new \nterminology, concepts, and infrastructure necessary for designing and implementing \nsophisticated applications. \nWe start this chapter by describing some of the application domains where stream \nprocessing technologies have been successfully employed (Section 2.2), focusing on \nthe distinctive characteristics of these applications that ma
# ...
